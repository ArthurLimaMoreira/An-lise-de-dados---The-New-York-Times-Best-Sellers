# %% [markdown]
# # The New York Times Best Sellers
#     Base de dados com o top 5 livros mais vendidos da semana segundo a revista The New York Times.
#
# # Período Analisado
#     Março de 2010 a Dezembro de 2019.
#
# # Objetivo da análise
#     Analisar quais livros e autores permaneceram por maior núme ro de semanas no topo da lista em cada categoria.
#     Autor: Arthur Lima Moreira
#     Link para download do dataset: https://www.kaggle.com/datasets/dhruvildave/new-york-times-best-sellers

# %% [markdown]
# # Importação do pandas e da base de dados

# %%
import pandas as pd
import matplotlib as plt

tabela = pd.read_csv('bestsellers.csv')
display(tabela)
# Out:
#       published_date                      list_name  \
# 0         2010-01-03                  Chapter Books
# 1         2010-01-03                  Chapter Books
# 2         2010-01-03                  Chapter Books
# 3         2010-01-03                  Chapter Books
# 4         2010-01-03                  Chapter Books
# ...              ...                            ...
# 61425     2019-12-29  Young Adult Paperback Monthly
# 61426     2019-12-29  Young Adult Paperback Monthly
# 61427     2019-12-29  Young Adult Paperback Monthly
# 61428     2019-12-29  Young Adult Paperback Monthly
# 61429     2019-12-29  Young Adult Paperback Monthly
#
#                    list_name_encoded  rank         isbn13      isbn10  \
# 0                      chapter-books     1  9780316036245  0316036242
# 1                      chapter-books     2  9780439023481  0439023483
# 2                      chapter-books     3  9780439023498  0439023491
# 3                      chapter-books     4  9780763644109  0763644102
# 4                      chapter-books     5  9780385738934  0385738935
# ...                              ...   ...            ...         ...
# 61425  young-adult-paperback-monthly     1  9780142412145  0142412147
# 61426  young-adult-paperback-monthly     2  9780593109069  0593109066
# 61427  young-adult-paperback-monthly     3  9781481438261  1481438263
# 61428  young-adult-paperback-monthly     4  9780553496710  0553496719
# 61429  young-adult-paperback-monthly     5  9780525555377  0525555374
#
#                           title  \
# 0              WITCH AND WIZARD
# 1              THE HUNGER GAMES
# 2                 CATCHING FIRE
# 3       THE MAGICIAN’S ELEPHANT
# 4                        FALLEN
# ...                         ...
# 61425               LET IT SNOW
# 61426        LOOKING FOR ALASKA
# 61427             LONG WAY DOWN
# 61428    THE SUN IS ALSO A STAR
# 61429  TURTLES ALL THE WAY DOWN
#
#                                                author  \
# 0            James Patterson and Gabrielle Charbonnet
# 1                                     Suzanne Collins
# 2                                     Suzanne Collins
# 3                                      Kate DiCamillo
# 4                                         Lauren Kate
# ...                                               ...
# 61425  John Green, Maureen Johnson and Lauren Myracle
# 61426                                      John Green
# 61427                                  Jason Reynolds
# 61428                                     Nicola Yoon
# 61429                                      John Green
#
#                                              description  \
# 0      One of each, brother and sister, flex their ne...
# 1      In a dystopian future, a girl fights for survi...
# 2         The protagonist of "The Hunger Games" returns.
# 3      An orphan in search of his sister follows a fo...
# 4      Thwarted love among misfits at a Savannah, Ga....
# ...                                                  ...
# 61425                                                NaN
# 61426                                                NaN
# 61427                                                NaN
# 61428                                                NaN
# 61429                                                NaN
#
#                                       amazon_product_url  price  weeks_on_list
# 0      https://www.amazon.com/Witch-Wizard-James-Patt...  17.99              1
# 1      https://www.amazon.com/The-Hunger-Games-Suzann...  17.99             67
# 2      https://www.amazon.com/Catching-Fire-Hunger-Ga...  17.99             16
# 3      https://www.amazon.com/The-Magicians-Elephant-...  16.99             15
# 4      https://www.amazon.com/Fallen-Lauren-Kate/dp/0...  17.99              2
# ...                                                  ...    ...            ...
# 61425  https://www.amazon.com/Let-It-Snow-Holiday-Rom...   0.00              0
# 61426  https://www.amazon.com/Looking-Alaska-John-Gre...   0.00              0
# 61427  https://www.amazon.com/Long-Way-Down-Jason-Rey...   0.00              0
# 61428  https://www.amazon.com/Sun-Also-Star-Nicola-Yo...   0.00              0
# 61429  https://www.amazon.com/Turtles-All-Down-John-G...   0.00              0
#
# [61430 rows x 12 columns]

# %% [markdown]
# # Deletando tabelas que não serão utilizadas na análise

# %%
tabela = tabela.drop('list_name_encoded', axis = 1)
tabela = tabela.drop('amazon_product_url', axis = 1)
tabela = tabela.drop('isbn10', axis = 1)
tabela = tabela.drop('isbn13', axis = 1)
tabela = tabela.drop('description', axis = 1)
display(tabela)
# Out:
#       published_date                      list_name  rank  \
# 0         2010-01-03                  Chapter Books     1
# 1         2010-01-03                  Chapter Books     2
# 2         2010-01-03                  Chapter Books     3
# 3         2010-01-03                  Chapter Books     4
# 4         2010-01-03                  Chapter Books     5
# ...              ...                            ...   ...
# 61425     2019-12-29  Young Adult Paperback Monthly     1
# 61426     2019-12-29  Young Adult Paperback Monthly     2
# 61427     2019-12-29  Young Adult Paperback Monthly     3
# 61428     2019-12-29  Young Adult Paperback Monthly     4
# 61429     2019-12-29  Young Adult Paperback Monthly     5
#
#                           title  \
# 0              WITCH AND WIZARD
# 1              THE HUNGER GAMES
# 2                 CATCHING FIRE
# 3       THE MAGICIAN’S ELEPHANT
# 4                        FALLEN
# ...                         ...
# 61425               LET IT SNOW
# 61426        LOOKING FOR ALASKA
# 61427             LONG WAY DOWN
# 61428    THE SUN IS ALSO A STAR
# 61429  TURTLES ALL THE WAY DOWN
#
#                                                author  price  weeks_on_list
# 0            James Patterson and Gabrielle Charbonnet  17.99              1
# 1                                     Suzanne Collins  17.99             67
# 2                                     Suzanne Collins  17.99             16
# 3                                      Kate DiCamillo  16.99             15
# 4                                         Lauren Kate  17.99              2
# ...                                               ...    ...            ...
# 61425  John Green, Maureen Johnson and Lauren Myracle   0.00              0
# 61426                                      John Green   0.00              0
# 61427                                  Jason Reynolds   0.00              0
# 61428                                     Nicola Yoon   0.00              0
# 61429                                      John Green   0.00              0
#
# [61430 rows x 7 columns]

# %% [markdown]
# # Quantidade de semanas

# %%
print(tabela['published_date'].value_counts().shape)
# 522 semanas de publicação no dataset
# Out:
# (522,)

# %% [markdown]
# # Verificando valores nulos

# %%
tabela.isnull().sum()
# Out:
# published_date     0
# list_name          0
# rank               0
# title              0
# author            69
# price              0
# weeks_on_list      0
# dtype: int64

# %% [markdown]
# Alterando os valores nulos de autores para 'Unknown'

# %%
tabela.fillna({'author': 'Unknown'}, inplace=True)
tabela.isnull().sum()
# Out:
# published_date    0
# list_name         0
# rank              0
# title             0
# author            0
# price             0
# weeks_on_list     0
# dtype: int64

# %% [markdown]
# # Analisando cada categoria individualmente

# %%
categorias = tabela['list_name'].value_counts(normalize = True)
lista_autores = tabela[['rank', 'list_name', 'author', 'weeks_on_list']].groupby(['rank', 'list_name', 'author']).max()
display(lista_autores)
display(categorias*100)
# Out:
#                                                                    weeks_on_list
# rank list_name                       author
# 1    Advice How-To and Miscellaneous Allie Brosh                               9
#                                      Bill Burnett and Dave Evans               1
#                                      Bob Bones                                 1
#                                      Bob Harper                                1
#                                      Bob Harper with Greg Critser              1
# ...                                                                          ...
# 5    Young Adult Paperback           Tommy Wallach                             6
#                                      Victoria Aveyard                         32
#      Young Adult Paperback Monthly   John Green                                0
#                                      Nic Stone                                 0
#                                      Nicola Yoon                               0
#
# [14220 rows x 1 columns]
# Series Books                            4.248738
# Trade Fiction Paperback                 4.248738
# Hardcover Fiction                       4.248738
# Hardcover Nonfiction                    4.248738
# Paperback Nonfiction                    4.248738
# Picture Books                           4.248738
# Combined Print and E-Book Nonfiction    3.776656
# Combined Print and E-Book Fiction       3.776656
# Hardcover Graphic Books                 3.011558
# Manga                                   3.011558
# Mass Market Paperback                   3.011558
# Paperback Graphic Books                 3.011558
# Advice How-To and Miscellaneous         2.840632
# Science                                 2.759238
# Business Books                          2.580173
# E-Book Fiction                          2.539476
# E-Book Nonfiction                       2.539476
# Sports                                  2.376689
# Hardcover Political Books               2.197623
# Childrens Middle Grade Hardcover        1.847631
# Young Adult Hardcover                   1.847631
# Food and Fitness                        1.456943
# Hardcover Advice                        1.408107
# Paperback Advice                        1.408107
# Chapter Books                           1.253459
# Paperback Books                         1.253459
# Young Adult                             1.147648
# Childrens Middle Grade                  1.147648
# Animals                                 1.025558
# Celebrities                             1.025558
# Family                                  1.025558
# Humor                                   1.025558
# Religion Spirituality and Faith         1.025558
# Travel                                  1.025558
# Culture                                 0.993000
# Games and Activities                    0.993000
# Fashion Manners and Customs             0.993000
# Education                               0.993000
# Health                                  0.993000
# Crime and Punishment                    0.993000
# Relationships                           0.993000
# Combined Print Nonfiction               0.960443
# Combined Print Fiction                  0.960443
# Expeditions Disasters and Adventures    0.919746
# Race and Civil Rights                   0.919746
# Espionage                               0.879049
# Paperback Business Books                0.854631
# Hardcover Business Books                0.854631
# Audio Nonfiction                        0.781377
# Audio Fiction                           0.781377
# Young Adult Paperback                   0.610451
# Childrens Middle Grade Paperback        0.610451
# Young Adult E-Book                      0.610451
# Childrens Middle Grade E-Book           0.610451
# Indigenous Americans                    0.423246
# Graphic Books and Manga                 0.105811
# Mass Market Monthly                     0.105811
# Middle Grade Paperback Monthly          0.105811
# Young Adult Paperback Monthly           0.105811
# Name: list_name, dtype: float64

# %% [markdown]
# #   Critério de separação de classes
# Para evitar conflitos de dados repetidos, serão utilizadas as classes (list_name) para separar o dataset inicial para cada novo estudo.

# %% [markdown]
# # Books Series - Análise

# %%
classe_series = tabela.loc[tabela['list_name'] == 'Series Books']
'''
preco = classe_series['price'].value_counts()
display(preco)
Como a coluna price não possui valor nesta categoria, pode ser deletada
'''
classe_series = classe_series.drop('price', axis = 1)
display(classe_series)
# Out:
#       published_date     list_name  rank                          title  \
# 60        2010-01-03  Series Books     1              THE TWILIGHT SAGA
# 61        2010-01-03  Series Books     2           DIARY OF A WIMPY KID
# 62        2010-01-03  Series Books     3  PERCY JACKSON & THE OLYMPIANS
# 63        2010-01-03  Series Books     4                 HOUSE OF NIGHT
# 64        2010-01-03  Series Books     5                   THE 39 CLUES
# ...              ...           ...   ...                            ...
# 61410     2019-12-29  Series Books     1                        DOG MAN
# 61411     2019-12-29  Series Books     2           DIARY OF A WIMPY KID
# 61412     2019-12-29  Series Books     3                   HARRY POTTER
# 61413     2019-12-29  Series Books     4             CAPTAIN UNDERPANTS
# 61414     2019-12-29  Series Books     5                   DORK DIARIES
#
#                          author  weeks_on_list
# 60              Stephenie Meyer            124
# 61                  Jeff Kinney             49
# 62                 Rick Riordan            128
# 63     PC Cast and Kristin Cast             69
# 64              various authors             32
# ...                         ...            ...
# 61410                Dav Pilkey            120
# 61411               Jeff Kinney            561
# 61412                JK Rowling            560
# 61413                Dav Pilkey            200
# 61414      Rachel Renée Russell            304
#
# [2610 rows x 6 columns]

# %% [markdown]
# # Books Series - Separação de maiores best-sellers
#     Amostragem de última semana em que os best-sellers apareceram na lista e número máximo de semanas que permaneceu na lista (acima de 100 semanas).

# %%
#   SELECIONANDO AS 10 SÉRIES DE LIVROS MAIS VENDIDAS
books_series = classe_series[['published_date', 'title', 'author', 'weeks_on_list']].groupby(['title', 'author'], as_index=False).max().sort_values(['weeks_on_list'], ascending=False)
books_series.rename(columns={'weeks_on_list': 'Weeks_on_list', 'published_date': 'Last_week_on_list', 'author': 'Author', 'title': 'Title'}, inplace=True)

display(books_series)
# Out:
#                              Title                Author Last_week_on_list  \
# 26            DIARY OF A WIMPY KID           Jeff Kinney        2019-12-29
# 39                    HARRY POTTER            JK Rowling        2019-12-29
# 73   PERCY JACKSON & THE OLYMPIANS          Rick Riordan        2019-09-15
# 29                    DORK DIARIES  Rachel Renée Russell        2019-12-29
# 59                MAGIC TREE HOUSE     Mary Pope Osborne        2014-06-15
# ..                             ...                   ...               ...
# 81                        SERAFINA         Robert Beatty        2017-07-23
# 107         THE REMNANT CHRONICLES        Mary E Pearson        2016-08-21
# 30                       EVERNIGHT          Claudia Gray        2010-03-28
# 22                        DC ICONS       various authors        2018-08-26
# 53                      L.A. CANDY         Lauren Conrad        2010-10-24
#
#      Weeks_on_list
# 26             561
# 39             560
# 73             517
# 29             304
# 59             276
# ..             ...
# 81               1
# 107              1
# 30               1
# 22               1
# 53               1
#
# [135 rows x 4 columns]

# %% [markdown]
# Gráfico dos mais vendidos acima a partir de 100 semanas na lista

# %%
ax_bseries = books_series.filter(items=['Title', 'Author', 'Weeks_on_list', 'Last_week_on_list'])\
                        .where(books_series.Weeks_on_list > 99)\
                        .groupby(['Title'])\
                        .max().sort_values(by='Weeks_on_list', ascending=False)\
                        .plot(figsize=(20,5), fontsize=10, grid=True)
ax_bseries.set_title('Books Series - Mais vendidos por mais de 99 semanas', fontsize=22)
# Out:
# Text(0.5, 1.0, 'Books Series - Mais vendidos por mais de 99 semanas')
